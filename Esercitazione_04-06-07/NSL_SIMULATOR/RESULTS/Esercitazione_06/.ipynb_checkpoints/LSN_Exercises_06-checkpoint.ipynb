# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 6</span>

# %% [markdown]
# In Statistical Mechanics the one-dimensional (1D) Ising Model is exactly resoluble. The Hamiltonian for a system of N spins with nearest neighbors interaction is given by (in the following I will assume units such that $\mu_B=1$ and $k_B=1$):
#
# $$
# H =
# -J\sum_{i=1}^N s_i s_{i+1}
# -\frac{h}{2}\sum_{i=1}^N (s_i + s_{i+1})
# $$
#
# where $\{ s_i \}_{i=1,N}$ are spin variables taking values in $\{-1;1\}$, $J>0$ (ferromagnetic model),and with the assumption $s_{N+1} = s_{1}$.
#
# The partition function for $N$ spins, $Z$, can be exactly computed and it turns out to be:
#
# $$
# Z=\sum_{\{ s_i \}} \exp \left( -\beta H\right) = \lambda_1^N + \lambda_2^N
# $$
#
# where
# $\lambda_{1,2} =
# e^{\beta J}
# \cosh (\beta h) \pm \left[ e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J) \right]^{1/2}$,
# and where $\beta=\frac{1}{k_b T} = \frac{1}{T}$.
# Once the partition function has been computed, the Helmholtz free energy is readly obtained as $A = -k_B T \ln Z$. All the thermodynamic quantities of interest can be deduced from $A$ or, equivalently, from $Z$:
#
# - the **Internal Energy** per spin (with $h=0$):
#
# $$
# \frac{U(N,T)}{N} = \frac{\langle H \rangle}{N}
# = \frac{1}{N} \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}
# = -\frac{1}{N}\frac{\partial \ln Z}{\partial \beta}
# \underset{h=0}= -J \tanh (\beta J) \Biggl( \frac{1 + \tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)} \Biggl)
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
points=100
T = np.linspace(0.2,3.0,num=points)
beta = 1/T
J = 1.0
Ns = 50
th = np.tanh(J/T)
thN= th**Ns
ch = 1/th
e = -J*( th + ch*thN )/( 1 + thN )
plt.plot(T, e)
plt.title('Ising 1D, internal energy')
plt.xlabel('T')
plt.ylabel('U/N')
plt.show()

# %% [markdown]
# - the **Heat Capacity** (with $h=0$):
#
# $$
# C(N,T) = \frac{\partial U(N,T)}{\partial T}
# = \frac{\partial \beta}{\partial T}\frac{\partial U}{\partial \beta}
# = -k_B\beta^2 \frac{\partial}{\partial \beta} \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z} \right] = \\
# = -k_B\beta^2 \left[ -\sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \sum_{\{ s_i \}} H \exp \left( -\beta H\right)\frac{\partial Z^{-1}}{\partial \beta} \right] = \\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]\frac{1}{Z}\frac{\partial Z}{\partial \beta} \right\} =\\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} - \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]^2 \right\} =
# k_B\beta^2 \left(\langle H^2 \rangle -\langle H \rangle^2 \right)
# $$
#
# $$
# \frac{C(N,T)}{N} = \frac{1}{N}\frac{\partial U(N,T)}{\partial T} =\\
# \underset{h=0}=
# k_B (\beta J)^2 \left\{ 1+\tanh^N (\beta J)+(N-1)\tanh^2 (\beta J)+(N-1)\frac{\tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)}
# - N \left[ \frac{\tanh (\beta J) + \tanh^{N-1} (\beta J)}{1+\tanh^N (\beta J)} \right]^2 \right\}
# $$

# %%
heat=((beta*J)**2)*(((1+thN+(Ns-1)*(th**2)+(Ns-1)*(ch**2)*thN)/(1+thN))-Ns*((th+ch*thN)/(1+thN))**2)
plt.plot(T, heat)
plt.title('Ising 1D, Heat capacity')
plt.xlabel('T')
plt.ylabel('C')
plt.show()

# %% [markdown]
# - The **magnetization** (with $h \not= 0$):
#
# Note that with $h=0$ the magnetization $M(N,T,h=0)=\langle \sum_{i=1,N}s_i \rangle =0$ because in 1D we cannot have a (ferromagnetic) phase transition in absence of an external magnetic field.
#
# $$
# M(N,T,h) = -\frac{\partial A}{\partial h} = k_B T \frac{\partial \ln Z}{\partial h} =
# \frac{1}{\beta} \frac{1}{Z}\frac{\partial}{\partial h}\sum_{\{ s_i \}} \exp \left( -\beta H\right) = \sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z} = \left\langle \sum_{i=1,N}s_i \right\rangle
# $$
#
# The exact formula from $M(N,T,h) = k_B T \dfrac{\partial \ln Z}{\partial h}$ is:
# $$
# \frac{M(N,T,h)}{N}=\frac{e^{\beta J}\; \sinh(\beta h)}{Z} \; \Bigl[\lambda_1^{N-1}\cdot \Bigl(1+\frac{e^{\beta J}\; \cosh(\beta h)}{\sqrt{e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J)}}\Bigr) + \lambda_2^{N-1}\cdot \Bigl(1-\frac{e^{\beta J}\; \cosh(\beta h)}{\sqrt{e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J)}}\Bigr)\Bigr]
# $$

# %%
h=0.02 #external field
b = 1/T

l1 = np.exp(b*J)*np.cosh(b*h)+np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
l2 = np.exp(b*J)*np.cosh(b*h)-np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
Z = l1**Ns + l2**Ns
M = (np.exp(b*J)*np.sinh(b*h)*((l1**(Ns-1))*(1+np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))) 
        + (l2**(Ns-1))*(1-np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J)))))/(Z)
plt.plot(T, M)
plt.title('Ising 1D, magnetization M with h = 0.02')
plt.xlabel('T')
plt.ylabel('$M$')
plt.show()

# %% [markdown]
# - The **magnetic susceptibility** (with $h=0$):
#
# $$
# \chi(N,T) = \frac{\partial M}{\partial h} =
# \frac{\partial}{\partial h}\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z} =\\
# = \beta\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right]^2 \frac{\exp \left( -\beta H\right)}{Z}
# -\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z}
# \frac{1}{Z}\frac{\partial Z}{\partial h} =
# \beta \left[ \left\langle \left( \sum_{i=1,N}s_i \right)^2 \right\rangle - \left\langle \sum_{i=1,N}s_i \right\rangle^2 \right] = \\
# \underset{h=0}= \beta \left[ \left\langle \left( \sum_{i=1,N}s_i \right)^2 \right\rangle \right] = \beta e^{2\beta J} \Biggl( \frac{1-\tanh^N (\beta J)}{1+\tanh^N (\beta J)} \Biggl)
# $$

# %%
X = beta*np.exp(2*beta*J)*(1-thN)/(1+thN)
plt.plot(T, X)
plt.title('Ising 1D, Susceptibility')
plt.xlabel('T')
plt.ylabel('$\chi$')
plt.show()

# %% [markdown]
# ### Exercise 06.1
#
# Complete the NSL_simulator code to simulate a 1D Ising model with the Gibbs sampling algorithm (the Metropolis algorithm is already implemented) to sample the Boltzmann's weight $p(\{ s_i \}) = \exp(-\beta H)/Z$. Verify the possibility to restart from a previous spin configuration.
#
# The code already computes the internal energy: $U(N,T) = \langle H \rangle$. Add the calculation of $C(N,T)$, $\chi(N,T)$, $M(N,T,h)$ and compute:
# 1. $U(N,T) = \langle H \rangle_{h=0}$
# 2. $C(N,T) = k_B \beta^2 (\langle H^2 \rangle_{h=0}-\langle H \rangle_{h=0}^2)$
# 3. $\chi(N,T) = \beta \langle (\sum_{i=1,N}s_i)^2 \rangle_{h=0}$
# 4. $M(N,T,h=0.02)= \langle \sum_{i=1,N}s_i \rangle_{h=0.02}$
#
# as a function of $T$ in the range $\left[0.5;2.0\right]$ for a system of $N=50$ spins with $J=1$.
#
# As usual, use data blocking and give an estimate of the statistical uncertainties.

# %% [markdown]
# - <span style="color:red">Show pictures of your estimations of $U(N,T)$, $C(N,T)$, $\chi(N,T)$, $M(N,T,h=0.02)$ and their uncertainties</span> obtained with a large number of *MC steps* (e.g. $M\ge 10^5$) compared with the exact curves. In the same picture show your results obtained with <span style="color:blue">both sampling methods, Metropolis and Gibbs</span>.
#
# A Monte Carlo step will consist in trying to flip one time all the spins of the system. Do not forget to equilibrate your simulations and to use blocking average with blocks large enough.

# %% [markdown]
# Here I show the trend of the total internal energy (in reduced units), which allowed me to understand the fluctuations of the system. It appears evident that the system reaches equilibration after $7500$ steps. That's why an initial equilibration period of $50000$ steps (better safe than sorry!) will be performed in the computation of the requested properties. The plot below shows $E/N$ against the step number, so it displays instantaneous values.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Caricamento dei dati
x, y, z = np.loadtxt("equilibration_ising.dat", usecols=(0, 2, 3), unpack=True)

# Plotto i dati
plt.errorbar(x, y, yerr=z) 
plt.title('Total internal energy per particle, $E/N$') 
plt.xlabel('Step') 
plt.ylabel('$E/N$') 
plt.grid(True) 

# Visualizzazione
plt.show()

# %% [markdown]
# In the following pictures, I plotted the requested properties as the temperature varies. At every fixed temperature, block averaging is implemented, and the block size is chosen to be $20000$ steps to eliminate autocorrelation. Typically, $20$ blocks are used, summing up to $4 \cdot 10^5$ steps. I used a Python script to automatically increment the temperature and restart the simulation. As you can see, there is great agreement between theoretical predictions and simulated values. I shifted the temperature values considered in the computation by the Metropolis algorithm and the Gibbs ones so that simulated results can both be seen in the same figure.

# %%
# Plotto la funzione teorica come linea
points = 100
T = np.linspace(0.2, 3.0, num=points)
beta = 1 / T
J = 1.0
Ns = 50
th = np.tanh(J / T)
thN = th**Ns
ch = 1 / th
e = -Ns * J * (th + ch * thN) / (1 + thN)
plt.plot(T, e, color='orange', label='Theoretical')

# Caricamento dei dati
x, y, z = np.loadtxt("total_energy_metropolis.dat", usecols=(0, 2, 3), unpack=True)
l, m, n = np.loadtxt("total_energy_gibbs.dat", usecols=(0, 2, 3), unpack=True)

# Plotto i dati come punti con barre d'errore
plt.errorbar(x, Ns*y, yerr=Ns*z, fmt='o', color='blue', label='Metropolis', markersize=3) 
plt.errorbar(l, Ns*m, yerr=Ns*n, fmt='o', color='violet', label='Gibbs', markersize=3)
plt.title('Estimation of the total internal energy ' r'$U(N,T) = \langle H \rangle_{h=0}$') 
plt.xlabel('Temperature $T$') 
plt.ylabel('Total internal energy $E$') 
plt.grid(True) 



# Visualizzazione
plt.legend()
plt.show()

# %%
# Plotto la funzione teorica come linea
heat=Ns*((beta*J)**2)*(((1+thN+(Ns-1)*(th**2)+(Ns-1)*(ch**2)*thN)/(1+thN))-Ns*((th+ch*thN)/(1+thN))**2)
plt.plot(T, heat, color='orange', label='Theoretical')

# Caricamento dei dati
x, y, z = np.loadtxt("specific_heat_metropolis.dat", usecols=(0, 2, 3), unpack=True)
l, m, n = np.loadtxt("specific_heat_gibbs.dat", usecols=(0, 2, 3), unpack=True)

# Plotto i dati come punti con barre d'errore
plt.errorbar(x, y, yerr=z, fmt='o', color='blue', label='Metropolis', markersize=3) 
plt.errorbar(l, m, yerr=n, fmt='o', color='violet', label='Gibbs', markersize=3)
plt.title('Estimation of the heat capacity ' r'$C(N,T) = k_B \beta^2 (\langle H^2 \rangle_{h=0}-\langle H \rangle_{h=0}^2)$') 
plt.xlabel('Temperature $T$') 
plt.ylabel('Heat capacity $C(N,T)$') 
plt.grid(True) 

# Visualizzazione
plt.legend()
plt.show()

# %%
# Plotto la funzione teorica come linea
X = Ns*beta*np.exp(2*beta*J)*(1-thN)/(1+thN)
plt.plot(T, X, color='orange', label='Theoretical')

# Caricamento dei dati
x, y, z = np.loadtxt("susceptibility_metropolis.dat", usecols=(0, 2, 3), unpack=True)
l, m, n = np.loadtxt("susceptibility_gibbs.dat", usecols=(0, 2, 3), unpack=True)

# Plotto i dati come punti con barre d'errore
plt.errorbar(x, y, yerr=z, fmt='o', color='blue', label='Metropolis', markersize=3)
plt.errorbar(l, m, yerr=n, fmt='o', color='violet', label='Gibbs', markersize=3)
plt.title('Estimation of the susceptibility ' r'$\chi(N,T) = \beta \langle (\sum_{i=1,N}s_i)^2 \rangle_{h=0}$') 
plt.xlabel('Temperature $T$') 
plt.ylabel('Susceptibility ' r'$\chi(N,T)$') 
plt.grid(True) 

# Visualizzazione
plt.legend()
plt.show()

# %%
# Plotto la funzione teorica come linea
h=0.02 #external field
l1 = np.exp(b*J)*np.cosh(b*h)+np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
l2 = np.exp(b*J)*np.cosh(b*h)-np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
Z = l1**Ns + l2**Ns
M = Ns*(np.exp(b*J)*np.sinh(b*h)*((l1**(Ns-1))*(1+np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))) 
        + (l2**(Ns-1))*(1-np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J)))))/(Z)
plt.plot(T, M, color='orange', label='Theoretical')

# Caricamento dei dati
x, y, z = np.loadtxt("magnetization_h_metropolis.dat", usecols=(0, 2, 3), unpack=True)
l, m, n = np.loadtxt("magnetization_h_gibbs.dat", usecols=(0, 2, 3), unpack=True)

# Plotto i dati come punti con barre d'errore
plt.errorbar(x, y, yerr=z, fmt='o', color='blue', label='Metropolis', markersize=3) 
plt.errorbar(l, m, yerr=n, fmt='o', color='violet', label='Gibbs', markersize=3)
plt.title('Estimation of the magentization ' r'$M(N,T,h=0.02)= \langle \sum_{i=1,N}s_i \rangle_{h=0.02}$') 
plt.xlabel('Temperature $T$') 
plt.ylabel('Magentization $M(N,T,h=0.02)$') 
plt.grid(True) 

# Visualizzazione
plt.legend()
plt.show()

# %% [markdown]
# # Observations
#
# Here I present some observations that arose while coding.
#
# - The most difficult property to compute was the heat capacity. For the other properties, our code was already implemented to compute averages using data blocking. However, $C(N,T) = k_B \beta^2 (\langle H^2 \rangle_{h=0} - \langle H \rangle_{h=0}^2)$ involves a difference between two averages. So, I couldn't compute $C(N,T)$ in the same scope as everything else. My choice was to compute $H$ and $H^2$ following the data blocking logic and eventually, in the average function, I computed $C(N,T)$. As far as the error is concerned, I assumed $C(N,T)$ itself as the measure and let the error function in the data blocking scheme do its job. For a moment, I was hesitant about doing so and even thought about computing the error propagation, but I eventually opted for the standard deviation of the mean (the error function mentioned before) because I thought one could see the heat capacity itself as the actual measure.
# - Sometimes (but not in our simple case) it can be smart to simulate starting from different initial configurations. This precaution could reveal the presence of metastable equilibrium configurations. In general, it is wise to choose the initial condition based on the hypothetical equilibrium configuration.
# - The range of temperatures shouldn't be too small because we want the system to be ergodic.
# - One little comment regards the request, "A Monte Carlo step will consist of trying to flip all the spins of the system once". Actually, what our code does is a little bit different. The for loop governing the step function is: `for(int i=0; i<_npart; i++) this->move(int(_rnd.Rannyu()*_npart))`, so it is clear that some randomness is added and we don't actually slide through every particle trying to flip it.
# - As the assignment suggests, I implemented a function to save the previous spin configuration before decreasing the temperature. This choice follows the already explained aim to be in the neighborhood of the equilibrium configuration and act with little perturbations.
# - Block lengths seem reasonably long enough to assume no correlation between blocks.
# - The computation of susceptibility and heat capacity in the code is only performed with no external magnetic field, but they can be generalized using statistical mechanics.
